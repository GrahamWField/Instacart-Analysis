# %% [markdown]
# # 4.8 Excercise Grouping Data & Aggregating Variables

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# loading the new prepared data frames

# %%
path = r'c:\Users\graha\Desktop\Career foundry\Chapter 4\Instacart Basket Analysis 09.02.2024'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived_variables.pkl'))

# %%
#creating the Subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 21)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  department_id  prices  _merge    price_range_loc  \
# 0         Soda  ...              7     9.0    both  Mid-range product
# 1         Soda  ...              7     9.0    both  Mid-range product
# 2         Soda  ...              7     9.0    both  Mid-range product
# 3         Soda  ...              7     9.0    both  Mid-range product
# 4         Soda  ...              7     9.0    both  Mid-range product
#
#      busiest_day  order_day_rank     Busiest_day    busiest_days  \
# 0  normally busy  Regularly busy  Regularly busy  Regularly busy
# 1  normally busy  Regularly busy  Regularly busy    Slowest days
# 2  normally busy  Regularly busy  Regularly busy    Slowest days
# 3     Least busy      Least busy      Least busy    Slowest days
# 4     Least busy      Least busy      Least busy    Slowest days
#
#      Busiest_days busiest_period_of_day
# 0  Regularly busy        Average orders
# 1    Slowest days        Average orders
# 2    Slowest days           Most orders
# 3    Slowest days        Average orders
# 4    Slowest days           Most orders
#
# [5 rows x 21 columns]

# %%
df.groupby('product_name')

# %% [markdown]
# # Aggregating Data with agg()

# %% [markdown]
# ### Performing a Single Aggregation

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# # Performing Multiple Aggregations

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # Aggregating Data with transform()

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  order_day  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# ..       ...      ...           ...        ...                ...
# 95   3226575      360             1          5                 12
# 96   1469869      377             3          5                 17
# 97   1927023      387             2          4                 10
# 98    858092      420             4          1                 19
# 99    119314      420             5          3                 19
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# ..                     ...         ...                ...        ...
# 95                     NaN         196                  1          0
# 96                     3.0         196                  9          0
# 97                    22.0         196                  3          0
# 98                    30.0         196                  2          0
# 99                    16.0         196                  2          1
#
#    product_name  ...  prices  _merge    price_range_loc    busiest_day  \
# 0          Soda  ...     9.0    both  Mid-range product  normally busy
# 1          Soda  ...     9.0    both  Mid-range product  normally busy
# 2          Soda  ...     9.0    both  Mid-range product  normally busy
# 3          Soda  ...     9.0    both  Mid-range product     Least busy
# 4          Soda  ...     9.0    both  Mid-range product     Least busy
# ..          ...  ...     ...     ...                ...            ...
# 95         Soda  ...     9.0    both  Mid-range product  normally busy
# 96         Soda  ...     9.0    both  Mid-range product  normally busy
# 97         Soda  ...     9.0    both  Mid-range product     Least busy
# 98         Soda  ...     9.0    both  Mid-range product  normally busy
# 99         Soda  ...     9.0    both  Mid-range product  normally busy
#
#     order_day_rank     Busiest_day    busiest_days    Busiest_days  \
# 0   Regularly busy  Regularly busy  Regularly busy  Regularly busy
# 1   Regularly busy  Regularly busy    Slowest days    Slowest days
# 2   Regularly busy  Regularly busy    Slowest days    Slowest days
# 3       Least busy      Least busy    Slowest days    Slowest days
# 4       Least busy      Least busy    Slowest days    Slowest days
# ..             ...             ...             ...             ...
# 95  Regularly busy  Regularly busy  Regularly busy  Regularly busy
# 96  Regularly busy  Regularly busy  Regularly busy  Regularly busy
# 97      Least busy      Least busy    Slowest days    Slowest days
# 98  Regularly busy  Regularly busy    Busiest days    Busiest days
# 99  Regularly busy  Regularly busy    Slowest days    Slowest days
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2            Most orders        10
# 3         Average orders        10
# 4            Most orders        10
# ..                   ...       ...
# 95           Most orders         3
# 96        Average orders         3
# 97           Most orders         8
# 98        Average orders        22
# 99        Average orders        22
#
# [100 rows x 22 columns]

# %%
#pd.options.display.max_rows = None - this will increase the size of the notebook

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
